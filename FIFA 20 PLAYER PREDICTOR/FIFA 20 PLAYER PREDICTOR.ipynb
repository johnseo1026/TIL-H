# %% [markdown]
# # How to predict your best footballers’ FIFA 20 ratings

# %% [markdown]
# ## DATA CLEANING

# %%
import types
import pandas as pd

df_data_1 = pd.read_csv('players_20.csv')
df_data_1.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
df_fifa = df_data_1
df_fifa.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
df_fifa1 = df_fifa[['short_name','age','overall','potential', 'value_eur', 'wage_eur']]
df_fifa1.shape
# Out:
# (18278, 6)

# %%
df_fifa1['value_eur'] = df_fifa1['value_eur']/1000000
df_fifa1['wage_eur'] = df_fifa1['wage_eur']/10000
# Out:
# C:\Users\Owner\.conda\envs\tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Owner\.conda\envs\tutorial\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_fifa1.head()
# Out:
#           short_name  age  overall  potential  value_eur  wage_eur
# 0           L. Messi   32       94         94       95.5      56.5
# 1  Cristiano Ronaldo   34       93         93       58.5      40.5
# 2          Neymar Jr   27       92         92      105.5      29.0
# 3           J. Oblak   26       91         93       77.5      12.5
# 4          E. Hazard   28       91         91       90.0      47.0

# %%
df_fifa1.corr()
# Out:
#                 age   overall  potential  value_eur  wage_eur
# age        1.000000  0.464305  -0.262872   0.081513  0.151031
# overall    0.464305  1.000000   0.646650   0.638230  0.573578
# potential -0.262872  0.646650   1.000000   0.580868  0.475490
# value_eur  0.081513  0.638230   0.580868   1.000000  0.858052
# wage_eur   0.151031  0.573578   0.475490   0.858052  1.000000

# %%
df_fifa1.describe()
# Out:
#                 age       overall     potential     value_eur      wage_eur
# count  18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean      25.283291     66.244994     71.546887      2.484038      0.945694
# std        4.656964      6.949953      6.139669      5.585481      2.135171
# min       16.000000     48.000000     49.000000      0.000000      0.000000
# 25%       22.000000     62.000000     67.000000      0.325000      0.100000
# 50%       25.000000     66.000000     71.000000      0.700000      0.300000
# 75%       29.000000     71.000000     75.000000      2.100000      0.800000
# max       42.000000     94.000000     95.000000    105.500000     56.500000

# %% [markdown]
# ## DATA EXPLORATION

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
plt.bar('age', 'overall', data = df_fifa1, color = 'blue')
plt.xlabel("Age")
plt.ylabel("Overall")
plt.show()

# %%
line1 = linear_model.LinearRegression()

# %%
df_Potential = df_fifa.loc[:, "potential"].values.reshape(-1,1)
df_Overall = df_fifa1.loc[:, "overall"].values.reshape(-1,1)

# %%
line1.fit(df_Potential, df_Overall)
pred1 = line1.predict(df_Potential)

# %%
plt.scatter('potential', 'overall', data = df_fifa, marker = 'x', color = 'red')
plt.xlabel("Potential")
plt.ylabel("Overall")
plt.plot(df_Potential, pred1, color='black')
plt.show()

# %% [markdown]
# ## ML MODELLING

# %%
import numpy as np
split = np.random.rand(len(df_fifa1)) < 0.875
train = df_fifa1[split]
test = df_fifa1[~split]

# %%
regr = linear_model.LinearRegression()

# %%
# training & fitting the model
fifa_x_train = train[['age','value_eur','potential','wage_eur']]
fifa_y_train = train[['overall']]
poly = PolynomialFeatures(degree=4)
fifa_x_train_poly = poly.fit_transform(fifa_x_train)
regr.fit(fifa_x_train_poly, fifa_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# testing the model
fifa_x_test = test[['age','value_eur','potential', 'wage_eur']]
fifa_y_test = test[['overall']]
fifa_x_test_poly = poly.fit_transform(fifa_x_test)

# %%
df_fifa_pred = regr.predict(fifa_x_test_poly)

# %%
r2_score(fifa_y_test, df_fifa_pred)
# Out:
# 0.9757502918711423

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(fifa_y_test, df_fifa_pred)
print("Pearson Correlation Coefficient: ", pearson_coef, "and a P-value of:", p_value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-237-9dfd6cd4e006> in <module>
#       1 from scipy import stats
#       2
# ----> 3 pearson_coef, p_value = stats.pearsonr(fifa_y_test, df_fifa_pred)
#       4 print("Pearson Correlation Coefficient: ", pearson_coef, "and a P-value of:", p_value)
#
# ~\.conda\envs\tutorial\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3517         return dtype(np.sign(x[1] - x[0])*np.sign(y[1] - y[0])), 1.0
#    3518
# -> 3519     xmean = x.mean(dtype=dtype)
#    3520     ymean = y.mean(dtype=dtype)
#    3521
#
# ~\.conda\envs\tutorial\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add

# %%
fifa_x_test['Predicted Ratings'] = df_fifa_pred
# Out:
# C:\Users\Owner\.conda\envs\tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_fifa2 = pd.merge(df_fifa1,fifa_x_test)
df_fifa2.head(20)
# Out:
#              short_name  age  overall  potential  value_eur  wage_eur  \
# 0             K. Mbappé   20       89         95       93.5      15.5
# 1              N. Kanté   28       89         90       66.0      23.5
# 2               M. Reus   30       88         88       56.0      17.0
# 3            M. Hummels   30       87         87       41.0      13.0
# 4            L. Insigne   28       87         87       52.0      14.0
# 5              Coutinho   27       86         86       46.5      17.5
# 6           C. Immobile   29       86         86       44.5      10.5
# 7   S. Milinković-Savić   24       85         90       50.5       7.3
# 8                  Saúl   24       85         89       49.5       7.7
# 9       Bruno Fernandes   24       85         88       49.0       2.4
# 10              Marcelo   31       85         85       28.0      20.5
# 11                Allan   28       85         85       38.0      11.0
# 12          Alex Telles   26       84         86       33.0       2.3
# 13              M. Özil   30       84         84       29.5      12.5
# 14            Y. Sommer   30       84         84       21.0       3.7
# 15           A. Martial   23       83         88       34.5      14.0
# 16     Anderson Talisca   25       83         88       34.5       3.8
# 17             L. Digne   25       83         86       28.5       9.7
# 18              Miranda   34       83         83        9.5       3.2
# 19           S. Khedira   32       83         83       19.5      13.5
#
#     Predicted Ratings
# 0          102.614454
# 1           86.072704
# 2           85.553846
# 3           86.691140
# 4           88.939603
# 5           89.609887
# 6           86.639471
# 7           84.371429
# 8           84.798629
# 9           84.105974
# 10          85.939240
# 11          86.257622
# 12          81.956168
# 13          85.648100
# 14          87.177038
# 15          82.852481
# 16          84.103840
# 17          82.413663
# 18          85.473961
# 19          85.014642

# %%
df_fifa_pred2 = regr.predict(fifa_x_train_poly)
fifa_x_train['Predicted Ratings'] = df_fifa_pred2
# Out:
# C:\Users\Owner\.conda\envs\tutorial\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_fifa3 = pd.merge(df_fifa1,fifa_x_train)
df_fifa3.head(20)
# Out:
#            short_name  age  overall  potential  value_eur  wage_eur  \
# 0            L. Messi   32       94         94       95.5      56.5
# 1   Cristiano Ronaldo   34       93         93       58.5      40.5
# 2           Neymar Jr   27       92         92      105.5      29.0
# 3            J. Oblak   26       91         93       77.5      12.5
# 4           E. Hazard   28       91         91       90.0      47.0
# 5        K. De Bruyne   28       91         91       90.0      37.0
# 6       M. ter Stegen   27       90         93       67.5      25.0
# 7         V. van Dijk   27       90         91       78.0      20.0
# 8           L. Modrić   33       90         90       45.0      34.0
# 9            M. Salah   27       90         90       80.5      24.0
# 10       K. Koulibaly   28       89         91       67.5      15.0
# 11            H. Kane   25       89         91       83.0      22.0
# 12            Alisson   26       89         91       58.0      15.5
# 13             De Gea   28       89         90       56.0      20.5
# 14       G. Chiellini   34       89         89       24.5      21.5
# 15          S. Agüero   31       89         89       60.0      30.0
# 16       Sergio Ramos   33       89         89       31.5      30.0
# 17          L. Suárez   32       89         89       53.0      35.5
# 18     R. Lewandowski   30       89         89       64.5      23.5
# 19    Sergio Busquets   30       89         89       55.0      30.0
#
#     Predicted Ratings
# 0           94.303460
# 1           88.395089
# 2           91.251910
# 3           92.795617
# 4           92.272672
# 5           89.718948
# 6           84.115617
# 7           88.281580
# 8           92.210184
# 9           94.662584
# 10          84.298378
# 11          91.801840
# 12          86.203192
# 13          86.568704
# 14          86.951411
# 15          90.772732
# 16          87.308279
# 17          91.880815
# 18          87.499183
# 19          87.230179

# %% [markdown]
# ## USING FIFA 19 ratings to predict FIFA 20 ratings

# %%
df_data_2 = pd.read_csv('players_19.csv')
df_data_2.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     193080  https://sofifa.com/player/193080/david-de-gea-...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# 2          Neymar Jr        Neymar da Silva Santos Junior   26  1992-02-05
# 3             De Gea                David De Gea Quintana   27  1990-11-07
# 4       K. De Bruyne                      Kevin De Bruyne   27  1991-06-28
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        187         83    Portugal             Juventus  ...  65+3  61+3
# 1        170         72   Argentina         FC Barcelona  ...  63+2  61+2
# 2        175         68      Brazil  Paris Saint-Germain  ...  65+3  60+3
# 3        193         76       Spain    Manchester United  ...   NaN   NaN
# 4        181         70     Belgium      Manchester City  ...  77+3  77+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 1  61+2  61+2  63+2  58+2  47+2  47+2  47+2  58+2
# 2  60+3  60+3  65+3  60+3  47+3  47+3  47+3  60+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
#
# [5 rows x 104 columns]

# %%
df_fifa4 = df_data_2[['short_name','age','overall','potential', 'value_eur', 'wage_eur']]

# %%
df_fifa4['value_eur'] = df_fifa4['value_eur']/1000000
df_fifa4['wage_eur'] = df_fifa4['wage_eur']/10000
# Out:
# C:\Users\Owner\.conda\envs\tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Owner\.conda\envs\tutorial\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_fifa4.head()
# Out:
#           short_name  age  overall  potential  value_eur  wage_eur
# 0  Cristiano Ronaldo   33       94         94       77.0      40.5
# 1           L. Messi   31       94         94      110.5      56.5
# 2          Neymar Jr   26       92         93      118.5      29.0
# 3             De Gea   27       91         93       72.0      26.0
# 4       K. De Bruyne   27       91         92      102.0      35.5

# %%
df_fifa4.head()
# Out:
#           short_name  age  overall  potential  value_eur  wage_eur
# 0  Cristiano Ronaldo   33       94         94       77.0      40.5
# 1           L. Messi   31       94         94      110.5      56.5
# 2          Neymar Jr   26       92         93      118.5      29.0
# 3             De Gea   27       91         93       72.0      26.0
# 4       K. De Bruyne   27       91         92      102.0      35.5

# %%
df_fifa4.corr()
# Out:
#                 age   overall  potential  value_eur  wage_eur
# age        1.000000  0.463201  -0.237430   0.082805  0.146146
# overall    0.463201  1.000000   0.665131   0.626512  0.574718
# potential -0.237430  0.665131   1.000000   0.576133  0.491614
# value_eur  0.082805  0.626512   0.576133   1.000000  0.861424
# wage_eur   0.146146  0.574718   0.491614   0.861424  1.000000

# %% [markdown]
# ## ML MODELLING

# %%
import numpy as np
split = np.random.rand(len(df_fifa4)) < 0.75
train2 = df_fifa4[split]
test2 = df_fifa4[~split]

# %%
regr2 = linear_model.LinearRegression()

# %%
# Training & fitting the model
fifa_x_train2 = train2[['age','value_eur','potential','wage_eur']]
fifa_y_train2 = train2[['overall']]
poly = PolynomialFeatures(degree=4)
fifa_x_train_poly2 = poly.fit_transform(fifa_x_train2)
regr2.fit(fifa_x_train_poly2, fifa_y_train2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Testing the model
fifa_x_test2 = test2[['age','value_eur','potential','wage_eur']]
fifa_y_test2 = test2[['overall']]
fifa_x_test_poly2 = poly.fit_transform(fifa_x_test2)

# %%
df_fifa_pred2 = regr2.predict(fifa_x_test_poly2)

# %%
r2_score(fifa_y_test2, df_fifa_pred2)
# Out:
# 0.9725021878348925

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(fifa_y_test2, df_fifa_pred2)
print("Pearson Correlation Coefficient: ", pearson_coef, "and a P-value of:", p_value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-254-7ddbaf741ac9> in <module>
#       1 from scipy import stats
#       2
# ----> 3 pearson_coef, p_value = stats.pearsonr(fifa_y_test2, df_fifa_pred2)
#       4 print("Pearson Correlation Coefficient: ", pearson_coef, "and a P-value of:", p_value)
#
# ~\.conda\envs\tutorial\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3517         return dtype(np.sign(x[1] - x[0])*np.sign(y[1] - y[0])), 1.0
#    3518
# -> 3519     xmean = x.mean(dtype=dtype)
#    3520     ymean = y.mean(dtype=dtype)
#    3521
#
# ~\.conda\envs\tutorial\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add

# %%
fifa_x_test2['Predicted Ratings'] = df_fifa_pred2
# Out:
# C:\Users\Owner\.conda\envs\tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_fifa5 = pd.merge(df_fifa4,fifa_x_test2)
df_fifa5.head(20)
# Out:
#        short_name  age  overall  potential  value_eur  wage_eur  \
# 0       Neymar Jr   26       92         93      118.5      29.0
# 1       E. Hazard   27       91         91       93.0      34.0
# 2     T. Courtois   26       90         91       62.0      25.0
# 3        T. Kroos   28       90         90       76.5      35.5
# 4            Isco   26       89         92       83.0      32.5
# 5     David Silva   32       89         89       51.5      27.5
# 6       E. Cavani   31       89         89       60.0      20.0
# 7       G. Buffon   40       88         88        4.0       7.7
# 8   S. Handanovič   33       88         88       30.0      11.0
# 9         Marcelo   30       88         88       43.0      28.5
# 10     L. Insigne   27       88         88       62.0      16.5
# 11  P. Aubameyang   29       87         87       50.5      22.0
# 12       K. Navas   31       87         87       30.5      19.5
# 13      R. Varane   25       86         92       51.5      21.0
# 14        M. Özil   29       86         86       43.5      19.0
# 15     M. Benatia   31       86         86       30.0      16.0
# 16     L. Bonucci   31       86         86       30.0      16.0
# 17      M. Pjanić   28       86         86       44.0      18.0
# 18     I. Perišić   29       86         86       43.5      12.0
# 19      T. Müller   28       86         86       46.0      14.5
#
#     Predicted Ratings
# 0           85.528863
# 1           91.338590
# 2           86.523480
# 3           88.917398
# 4           82.756824
# 5           85.850316
# 6           85.223055
# 7           80.350658
# 8           81.602478
# 9           91.937476
# 10          88.152034
# 11          85.811265
# 12          91.077675
# 13          90.259890
# 14          84.958845
# 15          88.795697
# 16          88.795697
# 17          84.340442
# 18          85.303049
# 19          84.572505

# %%
df_fifa_pred3 = regr2.predict(fifa_x_train_poly2)

# %%
fifa_x_train2['Predicted Ratings'] = df_fifa_pred3
# Out:
# C:\Users\Owner\.conda\envs\tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_fifa6 = pd.merge(df_fifa4,fifa_x_train2)
df_fifa6.head(20)
# Out:
#            short_name  age  overall  potential  value_eur  wage_eur  \
# 0   Cristiano Ronaldo   33       94         94       77.0      40.5
# 1            L. Messi   31       94         94      110.5      56.5
# 2              De Gea   27       91         93       72.0      26.0
# 3        K. De Bruyne   27       91         92      102.0      35.5
# 4        Sergio Ramos   32       91         91       51.0      38.0
# 5           L. Suárez   31       91         91       80.0      45.5
# 6           L. Modrić   32       91         91       67.0      42.0
# 7            J. Oblak   25       90         93       68.0       9.4
# 8            M. Neuer   32       90         90       44.0      13.5
# 9            D. Godín   32       90         90       44.0      12.5
# 10     R. Lewandowski   29       90         90       77.0      20.5
# 11          P. Dybala   24       89         94       89.0      20.5
# 12      M. ter Stegen   26       89         92       58.0      24.0
# 13            H. Kane   24       89         92       86.0      20.5
# 14       A. Griezmann   27       89         90       78.0      14.5
# 15           N. Kanté   27       89         90       63.0      22.5
# 16       G. Chiellini   33       89         89       27.0      21.5
# 17          S. Agüero   30       89         89       64.5      30.0
# 18         M. Hummels   29       89         89       51.5      16.5
# 19         C. Eriksen   26       88         91       73.5      20.5
#
#     Predicted Ratings
# 0           94.207316
# 1           94.976168
# 2           99.258252
# 3           88.560357
# 4           92.785656
# 5           89.888971
# 6           88.688461
# 7           87.006550
# 8           81.950199
# 9           80.646155
# 10          90.618741
# 11          87.553937
# 12          92.303928
# 13          91.720368
# 14          90.959042
# 15          87.342138
# 16          85.862090
# 17          89.556382
# 18          90.854537
# 19          88.672092

# %%
df_fifa7 = df_fifa1[['age','value_eur','potential','wage_eur']]
df_fifa8 = poly.fit_transform(df_fifa7)

# %%
df_fifa_pred4 = regr2.predict(df_fifa8)

# %%
df_fifa7['FIFA 20 Predicted Ratings'] = df_fifa_pred4
# Out:
# C:\Users\Owner\.conda\envs\tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_fifa7.head()
# Out:
#    age  value_eur  potential  wage_eur  FIFA 20 Predicted Ratings
# 0   32       95.5         94      56.5                  82.291854
# 1   34       58.5         93      40.5                  64.097321
# 2   27      105.5         92      29.0                  92.957195
# 3   26       77.5         93      12.5                  91.144814
# 4   28       90.0         91      47.0                  75.746490

# %%
df_fifa9 = pd.merge(df_fifa1,df_fifa7)

# %%
df_fifa9.head(20)
# Out:
#            short_name  age  overall  potential  value_eur  wage_eur  \
# 0            L. Messi   32       94         94       95.5      56.5
# 1   Cristiano Ronaldo   34       93         93       58.5      40.5
# 2           Neymar Jr   27       92         92      105.5      29.0
# 3            J. Oblak   26       91         93       77.5      12.5
# 4           E. Hazard   28       91         91       90.0      47.0
# 5        K. De Bruyne   28       91         91       90.0      37.0
# 6       M. ter Stegen   27       90         93       67.5      25.0
# 7         V. van Dijk   27       90         91       78.0      20.0
# 8           L. Modrić   33       90         90       45.0      34.0
# 9            M. Salah   27       90         90       80.5      24.0
# 10          K. Mbappé   20       89         95       93.5      15.5
# 11       K. Koulibaly   28       89         91       67.5      15.0
# 12            H. Kane   25       89         91       83.0      22.0
# 13            Alisson   26       89         91       58.0      15.5
# 14             De Gea   28       89         90       56.0      20.5
# 15           N. Kanté   28       89         90       66.0      23.5
# 16       G. Chiellini   34       89         89       24.5      21.5
# 17          S. Agüero   31       89         89       60.0      30.0
# 18       Sergio Ramos   33       89         89       31.5      30.0
# 19          L. Suárez   32       89         89       53.0      35.5
#
#     FIFA 20 Predicted Ratings
# 0                   82.291854
# 1                   64.097321
# 2                   92.957195
# 3                   91.144814
# 4                   75.746490
# 5                   91.092538
# 6                  100.657269
# 7                   91.719722
# 8                   82.102443
# 9                   91.078120
# 10                  93.119189
# 11                  94.475505
# 12                  92.203783
# 13                  90.666801
# 14                  91.456945
# 15                  89.295722
# 16                  77.692244
# 17                  88.915261
# 18                  85.197352
# 19                  86.041645

# %%
# The predicted top 20 rated FIFA 20 footballers
df_fifa9 = df_fifa9.sort_values('FIFA 20 Predicted Ratings', ascending = False).reset_index()
df_fifa9.drop("index", axis = 1, inplace = True)
df_fifa9.head(20)
# Out:
#          short_name  age  overall  potential  value_eur  wage_eur  \
# 0     M. ter Stegen   27       90         93       67.5      25.0
# 1      K. Koulibaly   28       89         91       67.5      15.0
# 2       R. Sterling   24       88         90       73.0      25.5
# 3         K. Mbappé   20       89         95       93.5      15.5
# 4         Neymar Jr   27       92         92      105.5      29.0
# 5        M. de Ligt   19       85         93       50.0       7.6
# 6           H. Kane   25       89         91       83.0      22.0
# 7       W. Szczęsny   29       86         88       37.5      13.5
# 8       V. van Dijk   27       90         91       78.0      20.0
# 9   Sergio Busquets   30       89         89       55.0      30.0
# 10        J. Sancho   19       84         92       44.5       6.1
# 11           De Gea   28       89         90       56.0      20.5
# 12         J. Oblak   26       91         93       77.5      12.5
# 13     K. De Bruyne   28       91         91       90.0      37.0
# 14         M. Salah   27       90         90       80.5      24.0
# 15          Alisson   26       89         91       58.0      15.5
# 16       Jordi Alba   30       87         87       40.0      24.0
# 17         N. Kanté   28       89         90       66.0      23.5
# 18      M. Rashford   21       83         88       35.5      12.5
# 19         A. Lopes   28       85         87       33.5       8.8
#
#     FIFA 20 Predicted Ratings
# 0                  100.657269
# 1                   94.475505
# 2                   94.007816
# 3                   93.119189
# 4                   92.957195
# 5                   92.266940
# 6                   92.203783
# 7                   91.757468
# 8                   91.719722
# 9                   91.656663
# 10                  91.582867
# 11                  91.456945
# 12                  91.144814
# 13                  91.092538
# 14                  91.078120
# 15                  90.666801
# 16                  89.360969
# 17                  89.295722
# 18                  89.279211
# 19                  89.137968

# %%
r2_score(df_fifa9['overall'], df_fifa9['FIFA 20 Predicted Ratings'])
# Out:
# 0.9736919525154265

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(df_fifa9['overall'], df_fifa9['FIFA 20 Predicted Ratings'])
print("Pearson Correlation Coefficient: ", pearson_coef, "and a P-value of:", p_value)
# Out:
# Pearson Correlation Coefficient:  0.9874115390351101 and a P-value of: 0.0
