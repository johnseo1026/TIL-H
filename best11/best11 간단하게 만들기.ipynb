# %% [markdown]
# # BEST 11 찾기

# %%
import pandas as pd
from pandas import DataFrame, Series


df = pd.read_csv("fifa20.csv")
df = df[['short_name','club','team_position','team_jersey_number', 'overall']]
df.shape
# Out:
# (18278, 5)

# %%
df.head(10)
# Out:
#           short_name                 club team_position team_jersey_number  \
# 0           L. Messi         FC Barcelona            RW                 10
# 1  Cristiano Ronaldo             Juventus            LW                  7
# 2          Neymar Jr  Paris Saint-Germain           CAM                 10
# 3           J. Oblak      Atl챕tico Madrid            GK                 13
# 4          E. Hazard          Real Madrid            LW                  7
# 5       K. De Bruyne      Manchester City            CM                 17
# 6      M. ter Stegen         FC Barcelona            GK                  1
# 7        V. van Dijk            Liverpool            CB                  4
# 8          L. Modri훶          Real Madrid            CM                 10
# 9           M. Salah            Liverpool            RW                 11
#
#    overall
# 0       94
# 1       93
# 2       92
# 3       91
# 4       91
# 5       91
# 6       90
# 7       90
# 8       90
# 9       90

# %%
is_GK = df['team_position'] == 'GK'
GK = df[is_GK]
GK.head()
# Out:
#        short_name               club team_position team_jersey_number  overall
# 3        J. Oblak    Atl챕tico Madrid            GK                 13       91
# 6   M. ter Stegen       FC Barcelona            GK                  1       90
# 13        Alisson          Liverpool            GK                  1       89
# 14         De Gea  Manchester United            GK                  1       89
# 25        Ederson    Manchester City            GK                 31       88

# %%
is_CB = df['team_position'] == 'CB'
CB = df[is_CB]
CB.head()
# Out:
#       short_name          club team_position team_jersey_number  overall
# 7    V. van Dijk     Liverpool            CB                  4       90
# 11  K. Koulibaly        Napoli            CB                 26       89
# 16  G. Chiellini      Juventus            CB                  3       89
# 18  Sergio Ramos   Real Madrid            CB                  4       89
# 29         Piqu챕  FC Barcelona            CB                  3       88

# %%
is_RB = df['team_position'] == 'RB'
RB = df[is_RB]
RB.head()
# Out:
#               short_name               club team_position team_jersey_number  \
# 61            J. Kimmich  FC Bayern M체nchen            RB                 32
# 94              Carvajal        Real Madrid            RB                  2
# 144          Azpilicueta            Chelsea            RB                 28
# 148            K. Walker    Manchester City            RB                  2
# 160  T. Alexander-Arnold          Liverpool            RB                 66
#
#      overall
# 61        86
# 94        85
# 144       84
# 148       84
# 160       83

# %%
is_LB = df['team_position'] == 'LB'
LB = df[is_LB]
LB.head()
# Out:
#        short_name               club team_position team_jersey_number  overall
# 51     Jordi Alba       FC Barcelona            LB                 18       87
# 82   A. Robertson          Liverpool            LB                 26       85
# 92       D. Alaba  FC Bayern M체nchen            LB                 27       85
# 101       Marcelo        Real Madrid            LB                 12       85
# 103   Alex Sandro           Juventus            LB                 12       85

# %%
is_CDM = df['team_position'] == 'CDM'
CDM = df[is_CDM]
CDM.head()
# Out:
#          short_name               club team_position team_jersey_number  \
# 21  Sergio Busquets       FC Barcelona           CDM                  5
# 24         P. Pogba  Manchester United           CDM                  6
# 42         Casemiro        Real Madrid           CDM                 14
# 44      Fernandinho    Manchester City           CDM                 25
# 52           Thiago  FC Bayern M체nchen           CDM                  6
#
#     overall
# 21       89
# 24       88
# 42       87
# 44       87
# 52       87

# %%
is_CM = df['team_position'] == 'CM'
CM = df[is_CM]
CM.head()
# Out:
#       short_name             club team_position team_jersey_number  overall
# 5   K. De Bruyne  Manchester City            CM                 17       91
# 8      L. Modri훶      Real Madrid            CM                 10       90
# 15      N. Kant챕          Chelsea            CM                  7       89
# 33   David Silva  Manchester City            CM                 21       88
# 36      T. Kroos      Real Madrid            CM                  8       88

# %%
is_RM = df['team_position'] == 'RM'
RM = df[is_RM]
RM.head()
# Out:
#           short_name               club team_position team_jersey_number  \
# 27        C. Eriksen  Tottenham Hotspur            RM                 23
# 105             Koke    Atl챕tico Madrid            RM                  6
# 108        J. Sancho  Borussia Dortmund            RM                  7
# 121         N. Fekir         Real Betis            RM                  8
# 127  Felipe Anderson    West Ham United            RM                  8
#
#      overall
# 27        88
# 105       85
# 108       84
# 121       84
# 127       84

# %%
is_LM = df['team_position'] == 'LM'
LM = df[is_LM]
LM.head()
# Out:
#          short_name               club team_position team_jersey_number  \
# 38    P. Aubameyang            Arsenal            LM                 14
# 168  Gon챌alo Guedes        Valencia CF            LM                  7
# 171     M. Rashford  Manchester United            LM                 10
# 176        T. Lemar    Atl챕tico Madrid            LM                 11
# 182     Y. Carrasco   Dalian YiFang FC            LM                 10
#
#      overall
# 38        88
# 168       83
# 171       83
# 176       83
# 182       83

# %%
is_CAM = df['team_position'] == 'CAM'
CAM = df[is_CAM]
CAM.head()
# Out:
#     short_name                 club team_position team_jersey_number  overall
# 2    Neymar Jr  Paris Saint-Germain           CAM                 10       92
# 37     M. Reus    Borussia Dortmund           CAM                 11       88
# 97    A. G처mez             Atalanta           CAM                 10       85
# 113    D. Alli    Tottenham Hotspur           CAM                 20       84
# 132  M. Ham큄챠k     Dalian YiFang FC           CAM                 17       84

# %%
is_LAM = df['team_position'] == 'LAM'
LAM = df[is_LAM]
LAM.head()
# Out:
#           short_name                     club team_position  \
# 306           Taison         Shakhtar Donetsk           LAM
# 340      David Neres                     Ajax           LAM
# 379   Renato Augusto  Beijing Sinobo Guoan FC           LAM
# 1844        F. Kainz               1. FC K철ln           LAM
# 1848      N. Sansone                  Bologna           LAM
#
#      team_jersey_number  overall
# 306                   7       82
# 340                   7       81
# 379                   5       81
# 1844                 30       75
# 1848                 10       75

# %%
is_RAM = df['team_position'] == 'RAM'
RAM = df[is_RAM]
RAM.head()
# Out:
#         short_name                     club team_position team_jersey_number  \
# 95       H. Ziyech                     Ajax           RAM                 22
# 305         Marlos         Shakhtar Donetsk           RAM                 11
# 832       Fernando  Beijing Sinobo Guoan FC           RAM                 11
# 976   I. Fern찼ndez              River Plate           RAM                 26
# 1265   R. Orsolini                  Bologna           RAM                  7
#
#       overall
# 95         85
# 305        82
# 832        78
# 976        78
# 1265       76

# %%
is_LW = df['team_position'] == 'LW'
LW = df[is_LW]
LW.head()
# Out:
#            short_name             club team_position team_jersey_number  \
# 1   Cristiano Ronaldo         Juventus            LW                  7
# 4           E. Hazard      Real Madrid            LW                  7
# 22       A. Griezmann     FC Barcelona            LW                 17
# 26        R. Sterling  Manchester City            LW                  7
# 39            S. Man챕        Liverpool            LW                 10
#
#     overall
# 1        93
# 4        91
# 22       89
# 26       88
# 39       88

# %%
is_RW = df['team_position'] == 'RW'
RW = df[is_RW]
RW.head()
# Out:
#         short_name                 club team_position team_jersey_number  \
# 0         L. Messi         FC Barcelona            RW                 10
# 9         M. Salah            Liverpool            RW                 11
# 10       K. Mbapp챕  Paris Saint-Germain            RW                  7
# 23       P. Dybala             Juventus            RW                 10
# 41  Bernardo Silva      Manchester City            RW                 20
#
#     overall
# 0        94
# 9        90
# 10       89
# 23       88
# 41       87

# %%
is_CF = df['team_position'] == 'CF'
CF = df[is_CF]
CF.head()
# Out:
#           short_name         club team_position team_jersey_number  overall
# 46        K. Benzema  Real Madrid            CF                  9       87
# 63   Roberto Firmino    Liverpool            CF                  9       86
# 434        J. Correa        Lazio            CF                 11       80
# 651          J. King  Bournemouth            CF                  7       79
# 741      Dyego Sousa  Shenzhen FC            CF                 40       79

# %%
is_LF = df['team_position'] == 'LF'
LF = df[is_LF]
LF.head()
# Out:
#           short_name                 club team_position team_jersey_number  \
# 259      K. Demirbay  Bayer 04 Leverkusen            LF                 10
# 1011       N. Vla큄i훶      PFC CSKA Moscow            LF                  8
# 1057  Alex Berenguer               Torino            LF                 21
# 1515   C. Villanueva           Al Ittihad            LF                 10
# 1826        D. Bessa        Hellas Verona            LF                  8
#
#       overall
# 259        82
# 1011       77
# 1057       77
# 1515       76
# 1826       75

# %%
is_RF = df['team_position'] == 'RF'
RF = df[is_RF]
RF.head()
# Out:
#         short_name                      club team_position team_jersey_number  \
# 109     K. Havertz       Bayer 04 Leverkusen            RF                 29
# 706    Iago Falqu챕                    Torino            RF                 10
# 1060  M. Ga훶inovi훶       Eintracht Frankfurt            RF                 11
# 1354     F. Kamano  FC Girondins de Bordeaux            RF                 11
# 1407      F. Klaus             VfL Wolfsburg            RF                 11
#
#       overall
# 109        84
# 706        79
# 1060       77
# 1354       76
# 1407       76

# %%
is_ST = df['team_position'] == 'ST'
ST = df[is_ST]
ST.head()
# Out:
#         short_name                 club team_position team_jersey_number  \
# 12         H. Kane    Tottenham Hotspur            ST                 10
# 17       S. Ag체ero      Manchester City            ST                 10
# 19       L. Su찼rez         FC Barcelona            ST                  9
# 20  R. Lewandowski    FC Bayern M체nchen            ST                  9
# 34       E. Cavani  Paris Saint-Germain            ST                  9
#
#     overall
# 12       89
# 17       89
# 19       89
# 20       89
# 34       88

# %% [markdown]
# ## 4-1-2-3

# %%
tac4123 = ("GK","RB", "CB", "CB", "LB", "CDM", "CM", "CM", "RW", "ST", "LW")
tac4123
# Out:
# ('GK', 'RB', 'CB', 'CB', 'LB', 'CDM', 'CM', 'CM', 'RW', 'ST', 'LW')

# %%
GK.head(1)
# Out:
#   short_name             club team_position team_jersey_number  overall
# 3   J. Oblak  Atl챕tico Madrid            GK                 13       91

# %%
LB.head(1)
# Out:
#     short_name          club team_position team_jersey_number  overall
# 51  Jordi Alba  FC Barcelona            LB                 18       87

# %%
CB.head(2)
# Out:
#       short_name       club team_position team_jersey_number  overall
# 7    V. van Dijk  Liverpool            CB                  4       90
# 11  K. Koulibaly     Napoli            CB                 26       89

# %%
RB.head(1)
# Out:
#     short_name               club team_position team_jersey_number  overall
# 61  J. Kimmich  FC Bayern M체nchen            RB                 32       86

# %%
CDM.head(1)
# Out:
#          short_name          club team_position team_jersey_number  overall
# 21  Sergio Busquets  FC Barcelona           CDM                  5       89

# %%
CM.head(2)
# Out:
#      short_name             club team_position team_jersey_number  overall
# 5  K. De Bruyne  Manchester City            CM                 17       91
# 8     L. Modri훶      Real Madrid            CM                 10       90

# %%
LW.head(1)
# Out:
#           short_name      club team_position team_jersey_number  overall
# 1  Cristiano Ronaldo  Juventus            LW                  7       93

# %%
ST.head(1)
# Out:
#    short_name               club team_position team_jersey_number  overall
# 12    H. Kane  Tottenham Hotspur            ST                 10       89

# %%
RW.head(1)
# Out:
#   short_name          club team_position team_jersey_number  overall
# 0   L. Messi  FC Barcelona            RW                 10       94

# %% [markdown]
# ## 4-2-3-1

# %%
GK.head(1)
# Out:
#   short_name             club team_position team_jersey_number  overall
# 3   J. Oblak  Atl챕tico Madrid            GK                 13       91

# %%
LB.head(1)
# Out:
#     short_name          club team_position team_jersey_number  overall
# 51  Jordi Alba  FC Barcelona            LB                 18       87

# %%
CB.head(2)
# Out:
#       short_name       club team_position team_jersey_number  overall
# 7    V. van Dijk  Liverpool            CB                  4       90
# 11  K. Koulibaly     Napoli            CB                 26       89

# %%
RB.head(1)
# Out:
#     short_name               club team_position team_jersey_number  overall
# 61  J. Kimmich  FC Bayern M체nchen            RB                 32       86

# %%
CM.head(2)
# Out:
#      short_name             club team_position team_jersey_number  overall
# 5  K. De Bruyne  Manchester City            CM                 17       91
# 8     L. Modri훶      Real Madrid            CM                 10       90

# %%
LW.head(1)
# Out:
#           short_name      club team_position team_jersey_number  overall
# 1  Cristiano Ronaldo  Juventus            LW                  7       93

# %%
RW.head(1)
# Out:
#   short_name          club team_position team_jersey_number  overall
# 0   L. Messi  FC Barcelona            RW                 10       94

# %%
CAM.head(1)
# Out:
#   short_name                 club team_position team_jersey_number  overall
# 2  Neymar Jr  Paris Saint-Germain           CAM                 10       92

# %%
ST.head(1)
# Out:
#    short_name               club team_position team_jersey_number  overall
# 12    H. Kane  Tottenham Hotspur            ST                 10       89

# %% [markdown]
# # 이미지화
